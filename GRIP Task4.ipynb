# %% [markdown]
# # GRIP: The Spark Foundation

# %% [markdown]
# # Data science and Business Analytics Intern

# %% [markdown]
# # Author: Swapna Singarapalli

# %% [markdown]
# # Task4- Exploratory Data Analysis on dataset Global Terrorism

# %%
import math
import warnings
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("globalterrorismdb_0718dist.csv", encoding="latin1")
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [5 rows x 135 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
# I'm just take important data in whole dataset those I'm using further processing.
df=df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
# Checking the null velues in data
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   state        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   city         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Target       181055 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
#  17  Motive       50561 non-null   object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 25.0+ MB

# %%
df.head()
# Out:
#    Year  Month  Day             Country    state                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# 0     1.0      0.0             Julio Guzman     NaN
# 1     0.0      0.0  Nadine Chaval, daughter     NaN
# 2     1.0      0.0                 Employee     NaN
# 3     NaN      NaN             U.S. Embassy     NaN
# 4     NaN      NaN           U.S. Consulate     NaN
#
#                                 Group                  Target_type  \
# 0                              MANO-D  Private Citizens & Property
# 1  23rd of September Communist League      Government (Diplomatic)
# 2                             Unknown          Journalists & Media
# 3                             Unknown      Government (Diplomatic)
# 4                             Unknown      Government (Diplomatic)
#
#   Weapon_type Motive
# 0     Unknown    NaN
# 1     Unknown    NaN
# 2     Unknown    NaN
# 3  Explosives    NaN
# 4  Incendiary    NaN

# %%
df.shape
# Out:
# (181691, 18)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'state', 'Region', 'city',
#        'latitude', 'longitude', 'AttackType', 'Killed', 'Wounded', 'Target',
#        'Summary', 'Group', 'Target_type', 'Weapon_type', 'Motive'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 9498

# %%
#Filling blanks

df["Killed"] = df["Killed"].fillna(0)
df["Wounded"] = df["Wounded"].fillna(0)
df["Casualty"] = df["Killed"] + df["Wounded"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   state        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   city         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       181691 non-null  float64
#  11  Wounded      181691 non-null  float64
#  12  Target       181055 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
#  17  Motive       50561 non-null   object
#  18  Casualty     181691 non-null  float64
# dtypes: float64(5), int64(3), object(11)
# memory usage: 26.3+ MB

# %%
YearAtck = df["Year"].value_counts(dropna = False).sort_index().to_frame().reset_index().rename(columns = {"index" : "Year", "Year" : "Attacks"}).set_index("Year")

# %%
YearAtck.info() #Information about Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 1970 to 2017
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Attacks  47 non-null     int64
# dtypes: int64(1)
# memory usage: 752.0 bytes

# %%
YearAtck.head() #Shows only first 5 rows of the data
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581

# %%
YearAtck.tail() ##Shows only last 5 rows of the data
# Out:
#       Attacks
# Year
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900

# %%
YearAtck #Shows the full data
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900

# %%
YearAtck.shape #Gives number of rows and columns
# Out:
# (47, 1)

# %%
YearAtck.describe() #Inform about important statistical terms depending on Data
# Out:
#             Attacks
# count     47.000000
# mean    3865.765957
# std     3836.943826
# min      471.000000
# 25%     1364.000000
# 50%     2870.000000
# 75%     4503.500000
# max    16903.000000

# %%
#Plot Attack Data

YearAtck.plot(kind = "bar", color = "orange", figsize = (20,10))
plt.title("Attacks per year")
plt.xlabel("Year")
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# The least number of attacks were in 1971 with attacks: 471
# The most number of attacks were in 2014 with attacks: 16960

# %%
#Yearwise Casualty

YearCas = df[["Year", "Casualty"]].groupby("Year").sum()

# %%
YearCas.info() #Information about Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 1970 to 2017
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Casualty  47 non-null     float64
# dtypes: float64(1)
# memory usage: 752.0 bytes

# %%
YearCas.head() #Shows only first 5 rows of the data
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0

# %%
YearCas.tail() ##Shows only last 5 rows of the dat
# Out:
#       Casualty
# Year
# 2013   59961.0
# 2014   85618.0
# 2015   82896.0
# 2016   74872.0
# 2017   51372.0

# %%
YearCas #Shows the full data
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0
# 1975    1234.0
# 1976    1430.0
# 1977     974.0
# 1978    3059.0
# 1979    4606.0
# 1980    8045.0
# 1981    8188.0
# 1982    8478.0
# 1983   13491.0
# 1984   15741.0
# 1985   12224.0
# 1986   10790.0
# 1987   12257.0
# 1988   14168.0
# 1989   13691.0
# 1990   13276.0
# 1991   16020.0
# 1992   19657.0
# 1994   15259.0
# 1995   20395.0
# 1996   17761.0
# 1997   19996.0
# 1998   12871.0
# 1999    8734.0
# 2000   10272.0
# 2001   30503.0
# 2002   11967.0
# 2003   10701.0
# 2004   17765.0
# 2005   19115.0
# 2006   24930.0
# 2007   35348.0
# 2008   28155.0
# 2009   28411.0
# 2010   23774.0
# 2011   22905.0
# 2012   40942.0
# 2013   59961.0
# 2014   85618.0
# 2015   82896.0
# 2016   74872.0
# 2017   51372.0

# %%
YearCas.shape #Gives number of rows and columns
# Out:
# (47, 1)

# %%
YearCas.describe() #Inform about important statistical terms depending on Data
# Out:
#            Casualty
# count     47.000000
# mean   19909.297872
# std    20602.941833
# min      255.000000
# 25%     8333.000000
# 50%    13691.000000
# 75%    23339.500000
# max    85618.000000

# %%
#Plot Casualty Data

YearCas.plot(kind = "bar", color = "teal", figsize = (20,10))
plt.title("Casualty per year")
plt.xlabel("Year")
plt.ylabel("Casualties")
plt.show()

# %% [markdown]
# The least number of casualties were in 1971 with casualties: 255
# The most number of casualties were in 2014 with casualties: 85791

# %%
#Yearwise Killed

YearKill = df[["Year", "Killed"]].groupby("Year").sum()

# %%
YearKill.info() #Information about Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 1970 to 2017
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Killed  47 non-null     float64
# dtypes: float64(1)
# memory usage: 752.0 bytes

# %%
YearKill.head() #Shows only first 5 rows of the data
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %%
YearKill.tail() ##Shows only last 5 rows of the data
# Out:
#        Killed
# Year
# 2013  22273.0
# 2014  44490.0
# 2015  38853.0
# 2016  34871.0
# 2017  26445.0

# %%
YearKill #Shows the full data
# Out:
#        Killed
# Year
# 1970    174.0
# 1971    173.0
# 1972    566.0
# 1973    370.0
# 1974    539.0
# 1975    617.0
# 1976    674.0
# 1977    456.0
# 1978   1459.0
# 1979   2100.0
# 1980   4400.0
# 1981   4851.0
# 1982   5136.0
# 1983   9444.0
# 1984  10450.0
# 1985   7094.0
# 1986   4976.0
# 1987   6482.0
# 1988   7208.0
# 1989   8152.0
# 1990   7148.0
# 1991   8429.0
# 1992   9742.0
# 1994   7690.0
# 1995   6103.0
# 1996   6966.0
# 1997  10924.0
# 1998   4688.0
# 1999   3393.0
# 2000   4403.0
# 2001   7729.0
# 2002   4805.0
# 2003   3317.0
# 2004   5743.0
# 2005   6331.0
# 2006   9380.0
# 2007  12824.0
# 2008   9157.0
# 2009   9273.0
# 2010   7827.0
# 2011   8246.0
# 2012  15497.0
# 2013  22273.0
# 2014  44490.0
# 2015  38853.0
# 2016  34871.0
# 2017  26445.0

# %%
YearKill.shape #Gives number of rows and columns
# Out:
# (47, 1)

# %%
YearKill.describe() #Inform about important statistical terms depending on Data
# Out:
#              Killed
# count     47.000000
# mean    8763.148936
# std     9663.222754
# min      173.000000
# 25%     3896.500000
# 50%     6966.000000
# 75%     9326.500000
# max    44490.000000

# %%
#Plot Killed Data

YearKill.plot(kind = "bar", color = "crimson", figsize = (20,10))
plt.title("Killed per year")
plt.xlabel("Year")
plt.ylabel("Kills")
plt.show()

# %%
#the most number of kills were in 2014 with kills: 44648

# %%
#Yearwise Wounded

YearWoun = df[["Year", "Wounded"]].groupby("Year").sum()

# %%
YearWoun.info() #Information about Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 1970 to 2017
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Wounded  47 non-null     float64
# dtypes: float64(1)
# memory usage: 752.0 bytes

# %%
YearWoun.head() #Shows only first 5 rows of the data
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %%
YearWoun.tail() ##Shows only last 5 rows of the data
# Out:
#       Wounded
# Year
# 2013  37688.0
# 2014  41128.0
# 2015  44043.0
# 2016  40001.0
# 2017  24927.0

# %%
YearWoun #Shows the full data
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0
# 1975    617.0
# 1976    756.0
# 1977    518.0
# 1978   1600.0
# 1979   2506.0
# 1980   3645.0
# 1981   3337.0
# 1982   3342.0
# 1983   4047.0
# 1984   5291.0
# 1985   5130.0
# 1986   5814.0
# 1987   5775.0
# 1988   6960.0
# 1989   5539.0
# 1990   6128.0
# 1991   7591.0
# 1992   9915.0
# 1994   7569.0
# 1995  14292.0
# 1996  10795.0
# 1997   9072.0
# 1998   8183.0
# 1999   5341.0
# 2000   5869.0
# 2001  22774.0
# 2002   7162.0
# 2003   7384.0
# 2004  12022.0
# 2005  12784.0
# 2006  15550.0
# 2007  22524.0
# 2008  18998.0
# 2009  19138.0
# 2010  15947.0
# 2011  14659.0
# 2012  25445.0
# 2013  37688.0
# 2014  41128.0
# 2015  44043.0
# 2016  40001.0
# 2017  24927.0

# %%
YearWoun.shape #Gives number of rows and columns
# Out:
# (47, 1)

# %%
YearWoun.describe() #Inform about important statistical terms depending on Data
# Out:
#             Wounded
# count     47.000000
# mean   11146.148936
# std    11427.482790
# min       82.000000
# 25%     3493.500000
# 50%     7162.000000
# 75%    15104.500000
# max    44043.000000

# %%
#Plot Wounded Data

YearWoun.plot(kind = "bar", color = "lightblue", figsize = (20,10))
plt.title("Wounded per year")
plt.xlabel("Year")
plt.ylabel("Wounds")
plt.show()

# %% [markdown]
# The least number of wounds were in 1971 with wounds: 82
# The most number of wounds were in 2015 with wounds: 44204

# %% [markdown]
# Visualize Data (Region)

# %%
#Region wise Attack

RegAtck = pd.crosstab(df.Year, df.Region)

# %%
RegAtck.info() #Information about Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 1970 to 2017
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Australasia & Oceania        47 non-null     int64
#  1   Central America & Caribbean  47 non-null     int64
#  2   Central Asia                 47 non-null     int64
#  3   East Asia                    47 non-null     int64
#  4   Eastern Europe               47 non-null     int64
#  5   Middle East & North Africa   47 non-null     int64
#  6   North America                47 non-null     int64
#  7   South America                47 non-null     int64
#  8   South Asia                   47 non-null     int64
#  9   Southeast Asia               47 non-null     int64
#  10  Sub-Saharan Africa           47 non-null     int64
#  11  Western Europe               47 non-null     int64
# dtypes: int64(12)
# memory usage: 4.8 KB

# %%
RegAtck.head() #Shows only first 5 rows of the data
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          28            472
# 1971            1               5                          55            247
# 1972            0               1                          53             73
# 1973            2               1                          19             64
# 1974            4               2                          42            111
#
# Region  South America  South Asia  Southeast Asia  Sub-Saharan Africa  \
# Year
# 1970               65           1              10                   3
# 1971               24           0               6                   2
# 1972               33           1              16                   4
# 1973               83           1               2                   4
# 1974               81           2               3                   7
#
# Region  Western Europe
# Year
# 1970                50
# 1971               125
# 1972               376
# 1973               290
# 1974               317

# %%
RegAtck.tail() ##Shows only last 5 rows of the data
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 2013                        1                           14             7
# 2014                        9                            5             9
# 2015                       14                            1            10
# 2016                       10                            3            17
# 2017                       12                            4             7
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 2013           15             165                        4560             32
# 2014           43             962                        6939             37
# 2015           28             684                        6036             62
# 2016            8             134                        6115             75
# 2017            7             110                        3780             97
#
# Region  South America  South Asia  Southeast Asia  Sub-Saharan Africa  \
# Year
# 2013              182        4612            1188                 999
# 2014              283        4998            1082                2321
# 2015              176        4585            1072                1964
# 2016              159        3639            1077                2077
# 2017              172        3430            1020                1970
#
# Region  Western Europe
# Year
# 2013               261
# 2014               215
# 2015               333
# 2016               273
# 2017               291

# %%
RegAtck #Shows the full data
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
# 1975                        0                            9             0
# 1976                        0                           45             0
# 1977                        0                           24             0
# 1978                        2                          199             0
# 1979                        2                          609             0
# 1980                        7                         1070             0
# 1981                        3                         1148             0
# 1982                        2                          996             0
# 1983                        0                          858             0
# 1984                       11                          681             0
# 1985                        7                          780             0
# 1986                        4                          393             0
# 1987                        3                          566             0
# 1988                       12                          495             0
# 1989                       29                          503             0
# 1990                       18                          316             0
# 1991                       10                          729             7
# 1992                       17                          212            77
# 1994                       14                          180            65
# 1995                       18                          168            55
# 1996                       19                          116            33
# 1997                        7                          117            49
# 1998                        6                            1            25
# 1999                        4                            8            24
# 2000                        6                           14            21
# 2001                        4                            8            18
# 2002                        2                            3             6
# 2003                        4                            8             7
# 2004                        0                            5             8
# 2005                        0                            3            11
# 2006                        2                            5             6
# 2007                        1                            4             4
# 2008                        8                            0            36
# 2009                        1                            9            31
# 2010                        1                            1             9
# 2011                        0                            1             9
# 2012                        0                            1            12
# 2013                        1                           14             7
# 2014                        9                            5             9
# 2015                       14                            1            10
# 2016                       10                            3            17
# 2017                       12                            4             7
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          28            472
# 1971            1               5                          55            247
# 1972            0               1                          53             73
# 1973            2               1                          19             64
# 1974            4               2                          42            111
# 1975           12               0                          44            159
# 1976            2               0                          55            125
# 1977            4               2                         211            149
# 1978           35               2                         128            117
# 1979           16               1                         455             79
# 1980            1               1                         437             75
# 1981            4               4                         312             77
# 1982            3               3                         290             86
# 1983           13               2                         334             47
# 1984           15               4                         268             67
# 1985           10               5                         133             44
# 1986           12               3                         196             53
# 1987           10               1                         202             35
# 1988           24               4                         246             30
# 1989           18              16                         465             44
# 1990           99              58                         494             37
# 1991           29              84                         612             40
# 1992           74              91                        1192             41
# 1994           34              95                        1051            101
# 1995           38              68                         590             94
# 1996           89             175                         373            111
# 1997           40             248                         548            137
# 1998            9             105                         247             37
# 1999            4             138                         316             56
# 2000           19             234                         272             41
# 2001           19             252                         362             48
# 2002            4             112                         326             33
# 2003            6             100                         310             34
# 2004            4              46                         492             12
# 2005            2              76                         882             22
# 2006            1              70                        1187             15
# 2007            0              62                        1385             18
# 2008           25             209                        1536             31
# 2009            8             165                        1361             16
# 2010            1             261                        1463             24
# 2011            4             198                        1663             12
# 2012            4             173                        2409             39
# 2013           15             165                        4560             32
# 2014           43             962                        6939             37
# 2015           28             684                        6036             62
# 2016            8             134                        6115             75
# 2017            7             110                        3780             97
#
# Region  South America  South Asia  Southeast Asia  Sub-Saharan Africa  \
# Year
# 1970               65           1              10                   3
# 1971               24           0               6                   2
# 1972               33           1              16                   4
# 1973               83           1               2                   4
# 1974               81           2               3                   7
# 1975               55           4               7                  12
# 1976               91           4              12                  11
# 1977              119           2               8                  29
# 1978              222           2              44                  46
# 1979              236          34              86                 124
# 1980              319          12              87                  58
# 1981              383          23              50                  98
# 1982              639          20              43                  60
# 1983              950          63              22                 106
# 1984             1492         244              46                 126
# 1985             1040         161             128                 141
# 1986             1184         273             102                 185
# 1987             1265         348             163                 174
# 1988             1041         801             242                 337
# 1989             1385         926             203                 291
# 1990             1076         601             348                 450
# 1991             1322         677             206                 271
# 1992             1204         545             279                 570
# 1994              373         376             151                 432
# 1995              255        1051             168                 239
# 1996              517         739             193                 217
# 1997              774         490             159                 279
# 1998              108         136              32                  87
# 1999              134         225             107                 143
# 2000              150         357             256                 191
# 2001              229         385             185                 162
# 2002              162         334             110                 121
# 2003              117         353             145                  73
# 2004               42         369              95                  34
# 2005               49         604             204                  60
# 2006               50         938             272                 114
# 2007               47         982             365                 302
# 2008              144        1759             514                 380
# 2009              159        1945             561                 283
# 2010              148        1981             473                 331
# 2011              106        2138             356                 494
# 2012              133        3803             587                1168
# 2013              182        4612            1188                 999
# 2014              283        4998            1082                2321
# 2015              176        4585            1072                1964
# 2016              159        3639            1077                2077
# 2017              172        3430            1020                1970
#
# Region  Western Europe
# Year
# 1970                50
# 1971               125
# 1972               376
# 1973               290
# 1974               317
# 1975               438
# 1976               578
# 1977               771
# 1978               729
# 1979              1020
# 1980               595
# 1981               484
# 1982               402
# 1983               475
# 1984               541
# 1985               466
# 1986               455
# 1987               416
# 1988               489
# 1989               444
# 1990               390
# 1991               696
# 1992               769
# 1994               584
# 1995               337
# 1996               476
# 1997               349
# 1998               141
# 1999               236
# 2000               253
# 2001               234
# 2002               120
# 2003               121
# 2004                59
# 2005               104
# 2006                98
# 2007                72
# 2008               163
# 2009               182
# 2010               133
# 2011                95
# 2012               193
# 2013               261
# 2014               215
# 2015               333
# 2016               273
# 2017               291

# %%
RegAtck.shape #Gives number of rows and columns
# Out:
# (47, 12)

# %%
RegAtck.describe() #Inform about important statistical terms depending on Data
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# count               47.000000                    47.000000     47.000000
# mean                 6.000000                   220.085106     11.978723
# std                  6.570686                   334.197340     18.292894
# min                  0.000000                     0.000000      0.000000
# 25%                  1.000000                     4.500000      0.000000
# 50%                  4.000000                    11.000000      6.000000
# 75%                  9.500000                   354.500000     14.500000
# max                 29.000000                  1148.000000     77.000000
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# count   47.000000       47.000000                   47.000000      47.000000
# mean    17.063830      109.446809                 1073.914894      73.531915
# std     22.102925      174.970284                 1667.022884      75.227438
# min      0.000000        0.000000                   19.000000      12.000000
# 25%      4.000000        3.000000                  228.500000      34.500000
# 50%      9.000000       68.000000                  373.000000      48.000000
# 75%     21.500000      151.500000                 1189.500000      90.000000
# max     99.000000      962.000000                 6939.000000     472.000000
#
# Region  South America   South Asia  Southeast Asia  Sub-Saharan Africa  \
# count       47.000000    47.000000       47.000000           47.000000
# mean       403.787234   956.893617      265.638298          373.404255
# std        448.002763  1374.782595      323.863392          577.860020
# min         24.000000     0.000000        2.000000            2.000000
# 25%        107.000000    28.500000       45.000000           60.000000
# 50%        172.000000   369.000000      159.000000          162.000000
# 75%        578.000000   960.000000      313.500000          334.000000
# max       1492.000000  4998.000000     1188.000000         2321.000000
#
# Region  Western Europe
# count        47.000000
# mean        354.021277
# std         220.615393
# min          50.000000
# 25%         172.500000
# 50%         333.000000
# 75%         475.500000
# max        1020.000000

# %%
#Plot Attack Region Data

RegAtck.plot(kind = "area", figsize = (20,10), stacked = False, alpha = 0.5)
plt.title("Region wise Attack")
plt.xlabel("Region")
plt.ylabel("Attacks")
plt.show()

# %%
#Terrorist Attack per Region

Reg_TA = RegAtck.transpose()
Reg_TA["Total"] = Reg_TA.sum(axis = 1)
RA = Reg_TA["Total"].sort_values(ascending = False)

# %%
RA.head() #Shows only first 5 rows of the data
# Out:
# Region
# Middle East & North Africa    50474
# South Asia                    44974
# South America                 18978
# Sub-Saharan Africa            17550
# Western Europe                16639
# Name: Total, dtype: int64

# %%
RA.tail() ##Shows only last 5 rows of the data
# Out:
# Region
# Eastern Europe           5144
# North America            3456
# East Asia                 802
# Central Asia              563
# Australasia & Oceania     282
# Name: Total, dtype: int64

# %%
RA #Shows the full data
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Total, dtype: int64

# %%
RA.shape #Gives number of rows and columns
# Out:
# (12,)

# %%
RA.describe() #Inform about important statistical terms depending on Data
# Out:
# count       12.000000
# mean     15140.916667
# std      16696.919414
# min        282.000000
# 25%       2792.500000
# 50%      11414.500000
# 75%      17907.000000
# max      50474.000000
# Name: Total, dtype: float64

# %%
#Plot Attack Data

RA.plot(kind = "bar", color = "orange", figsize = (20,10))
plt.title("Number of Attacks per Region")
plt.xlabel("Region")
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# The least number of attacks were in Australasia and Oceania with attacks: 325
# The most number of attacks were in Middle East & North Africa with attacks: 58252

# %%
#Regionwise Casualty

RegCas = df[["Region", "Casualty"]].groupby("Region").sum().sort_values(by = "Casualty", ascending = False)

# %%
RegCas.info() #Information about Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Middle East & North Africa to Australasia & Oceania
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Casualty  12 non-null     float64
# dtypes: float64(1)
# memory usage: 192.0+ bytes

# %%
RegCas.head() #Shows only first 5 rows of the data
# Out:
#                             Casualty
# Region
# Middle East & North Africa  351950.0
# South Asia                  242679.0
# Sub-Saharan Africa          131243.0
# South America                45553.0
# Southeast Asia               41896.0

# %%
RegCas.tail() ##Shows only last 5 rows of the data
# Out:
#                        Casualty
# Region
# Western Europe          25026.0
# Eastern Europe          19460.0
# East Asia               10365.0
# Central Asia             3009.0
# Australasia & Oceania     410.0

# %%
RegCas #Shows the full data
# Out:
#                              Casualty
# Region
# Middle East & North Africa   351950.0
# South Asia                   242679.0
# Sub-Saharan Africa           131243.0
# South America                 45553.0
# Southeast Asia                41896.0
# Central America & Caribbean   37699.0
# North America                 26447.0
# Western Europe                25026.0
# Eastern Europe                19460.0
# East Asia                     10365.0
# Central Asia                   3009.0
# Australasia & Oceania           410.0

# %%
RegCas.shape #Gives number of rows and columns
# Out:
# (12, 1)

# %%
RegCas.describe() #Inform about important statistical terms depending on Data
# Out:
#             Casualty
# count      12.000000
# mean    77978.083333
# std    110409.281372
# min       410.000000
# 25%     17186.250000
# 50%     32073.000000
# 75%     66975.500000
# max    351950.000000

# %%
#Plot Casualty Data

RegCas.plot(kind = "bar", color = "teal", figsize = (20,10))
plt.title("Casualty per Region")
plt.xlabel("Region")
plt.ylabel("Casualties")
plt.show()

# %% [markdown]
# The least number of casualties were in Australasia and Oceania with casualties: 519
# The most number of casualties were in Middle East and North Africa with casualties: 378559

# %%
#Regionwise Killed

RegKill = df[["Region", "Killed"]].groupby("Region").sum()

# %%
RegKill.info() #Information about Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Australasia & Oceania to Western Europe
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Killed  12 non-null     float64
# dtypes: float64(1)
# memory usage: 192.0+ bytes

# %%
RegKill.head() #Shows only first 5 rows of the data
# Out:
#                               Killed
# Region
# Australasia & Oceania          150.0
# Central America & Caribbean  28708.0
# Central Asia                  1000.0
# East Asia                     1152.0
# Eastern Europe                7415.0

# %%
RegKill.tail() ##Shows only last 5 rows of the data
# Out:
#                       Killed
# Region
# South America        28849.0
# South Asia          101319.0
# Southeast Asia       15637.0
# Sub-Saharan Africa   78386.0
# Western Europe        6694.0

# %%
RegKill #Shows the full data
# Out:
#                                Killed
# Region
# Australasia & Oceania           150.0
# Central America & Caribbean   28708.0
# Central Asia                   1000.0
# East Asia                      1152.0
# Eastern Europe                 7415.0
# Middle East & North Africa   137642.0
# North America                  4916.0
# South America                 28849.0
# South Asia                   101319.0
# Southeast Asia                15637.0
# Sub-Saharan Africa            78386.0
# Western Europe                 6694.0

# %%
RegKill.shape #Gives number of rows and columns
# Out:
# (12, 1)

# %%
RegKill.describe() #Inform about important statistical terms depending on Data
# Out:
#               Killed
# count      12.000000
# mean    34322.333333
# std     45970.536504
# min       150.000000
# 25%      3975.000000
# 50%     11526.000000
# 75%     41233.250000
# max    137642.000000

# %%
#Plot Killed Data

RegKill.plot(kind = "bar", color = "crimson", figsize = (20,10))
plt.title("Killed per Region")
plt.xlabel("Region")
plt.ylabel("Kills")
plt.show()

# %% [markdown]
# The least number of kills were in Australasia and Oceania with kills: 205
# The most number of kills were in Middle East & North Africa with kills: 149739

# %%
#Regionwise Wounded

RegWoun = df[["Region", "Wounded"]].groupby("Region").sum()

# %%
RegWoun.info() #Information about Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Australasia & Oceania to Western Europe
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Wounded  12 non-null     float64
# dtypes: float64(1)
# memory usage: 192.0+ bytes

# %%
RegWoun.head() #Shows only first 5 rows of the data
# Out:
#                              Wounded
# Region
# Australasia & Oceania          260.0
# Central America & Caribbean   8991.0
# Central Asia                  2009.0
# East Asia                     9213.0
# Eastern Europe               12045.0

# %%
RegWoun.tail() ##Shows only last 5 rows of the data
# Out:
#                      Wounded
# Region
# South America        16704.0
# South Asia          141360.0
# Southeast Asia       26259.0
# Sub-Saharan Africa   52857.0
# Western Europe       18332.0

# %%
RegWoun #Shows the full data
# Out:
#                               Wounded
# Region
# Australasia & Oceania           260.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# East Asia                      9213.0
# Eastern Europe                12045.0
# Middle East & North Africa   214308.0
# North America                 21531.0
# South America                 16704.0
# South Asia                   141360.0
# Southeast Asia                26259.0
# Sub-Saharan Africa            52857.0
# Western Europe                18332.0

# %%
RegWoun.shape #Gives number of rows and columns
# Out:
# (12, 1)

# %%
RegWoun.describe() #Inform about important statistical terms depending on Data
# Out:
#             Wounded
# count      12.00000
# mean    43655.75000
# std     66001.13281
# min       260.00000
# 25%      9157.50000
# 50%     17518.00000
# 75%     32908.50000
# max    214308.00000

# %%
#Plot Wounded Data

RegWoun.plot(kind = "bar", color = "lightblue", figsize = (20,10))
plt.title("Wounded per Region")
plt.xlabel("Region")
plt.ylabel("Wounds")
plt.show()

# %% [markdown]
# The least number of wounds were in Australasia and Oceania with wounds 314
# The most number of wounds were in Middle East & North Africa with wounds 228820

# %% [markdown]
# Visualize Data (Country{Top 20})

# %%
#Country wise Attack

CounAtck = df["Country"].value_counts().head(20)

# %%
CounAtck.head() #Shows only first 5 rows of the data
# Out:
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306
# Name: Country, dtype: int64

# %%
CounAtck.tail() ##Shows only last 5 rows of the data
# Out:
# Sri Lanka        3022
# United States    2836
# Algeria          2743
# France           2693
# Egypt            2479
# Name: Country, dtype: int64

# %%
CounAtck #Shows the full data
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: Country, dtype: int64

# %%
CounAtck.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
CounAtck.describe() #Inform about important statistical terms depending on Data
# Out:
# count       20.000000
# mean      6605.950000
# std       5528.927377
# min       2479.000000
# 25%       3192.250000
# 50%       4217.000000
# 75%       7257.500000
# max      24636.000000
# Name: Country, dtype: float64

# %%
#Plot Attack Data

CounAtck.plot(kind = "bar", color = "orange", figsize = (20,10))
plt.title("Attacks per Country")
plt.xlabel("Country")
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# The least number of attacks were in France with attacks: 2751
# The most number of attacks were in Iraq with attacks: 27521

# %%
CounCas = df["Country"].value_counts().head(20)

# %%
CounCas.head() #Shows only first 5 rows of the data
# Out:
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306
# Name: Country, dtype: int64

# %%
CounCas.tail() ##Shows only last 5 rows of the data
# Out:
# Sri Lanka        3022
# United States    2836
# Algeria          2743
# France           2693
# Egypt            2479
# Name: Country, dtype: int64

# %%
CounCas #Shows the full data
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: Country, dtype: int64

# %%
CounCas.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
CounCas.describe() #Inform about important statistical terms depending on Data
# Out:
# count       20.000000
# mean      6605.950000
# std       5528.927377
# min       2479.000000
# 25%       3192.250000
# 50%       4217.000000
# 75%       7257.500000
# max      24636.000000
# Name: Country, dtype: float64

# %%
#Plot Casualty Data

CounCas.plot(kind = "bar", color = "teal", figsize = (20,10))
plt.title("Casualty per Country")
plt.xlabel("Country")
plt.ylabel("Casualty")
plt.show()

# %% [markdown]
# The least number of casualties were in France with casualties: 2751
# The most number of casualties were in Iraq with casualties: 27521

# %%
#Country wise Killed

CounKill = df["Country"].value_counts().head(20)

# %%
CounKill.head() #Shows only first 5 rows of the data
# Out:
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306
# Name: Country, dtype: int64

# %%
CounKill.tail() ##Shows only last 5 rows of the data
# Out:
# Sri Lanka        3022
# United States    2836
# Algeria          2743
# France           2693
# Egypt            2479
# Name: Country, dtype: int64

# %%
CounKill #Shows the full data
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: Country, dtype: int64

# %%
CounKill.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
CounKill.describe() #Inform about important statistical terms depending o
# Out:
# count       20.000000
# mean      6605.950000
# std       5528.927377
# min       2479.000000
# 25%       3192.250000
# 50%       4217.000000
# 75%       7257.500000
# max      24636.000000
# Name: Country, dtype: float64

# %%
#Plot Killed Data

CounKill.plot(kind = "bar", color = "crimson", figsize = (20,10))
plt.title("Killed per Country")
plt.xlabel("Country")
plt.ylabel("Killed")
plt.show()

# %% [markdown]
# The least number of kills were in France with kills: 2751
# The most number of kills were in Iraq with kills: 27521

# %%
#Country wise Wounded

CounWoun = df[["Country", "Wounded"]].value_counts().head(20)

# %%
CounWoun.head() #Shows only first 5 rows of the data
# Out:
# Country      Wounded
# Iraq         0.0        9538
# Pakistan     0.0        9015
# India        0.0        8242
# Colombia     0.0        6677
# Afghanistan  0.0        6251
# dtype: int64

# %%
CounWoun.tail() ##Shows only last 5 rows of the data
# Out:
# Country   Wounded
# Thailand  0.0        2319
# Yemen     0.0        2207
# Chile     0.0        2106
# Iraq      2.0        2094
#           1.0        2089
# dtype: int64

# %%
CounWoun #Shows the full da
# Out:
# Country         Wounded
# Iraq            0.0        9538
# Pakistan        0.0        9015
# India           0.0        8242
# Colombia        0.0        6677
# Afghanistan     0.0        6251
# Peru            0.0        5236
# Philippines     0.0        4669
# El Salvador     0.0        4559
# United Kingdom  0.0        4322
# Nigeria         0.0        2882
# Turkey          0.0        2836
# Somalia         0.0        2827
# Spain           0.0        2596
# United States   0.0        2476
# France          0.0        2403
# Thailand        0.0        2319
# Yemen           0.0        2207
# Chile           0.0        2106
# Iraq            2.0        2094
#                 1.0        2089
# dtype: int64

# %%
CounWoun.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
CounWoun.describe() #Inform about important statistical terms depending on Data
# Out:
# count      20.000000
# mean     4267.200000
# std      2457.519301
# min      2089.000000
# 25%      2382.000000
# 50%      2859.000000
# 75%      5489.750000
# max      9538.000000
# dtype: float64

# %%
#Plot Wounded Data

CounWoun.plot(kind = "bar", color = "lightblue", figsize = (20,10))
plt.title("Wounded per Country")
plt.xlabel("Country")
plt.ylabel("Wounded")
plt.show()

# %% [markdown]
# The least number of wounds were in France with wounds: 2751
# The most number of wounds were in Iraq with wounds: 27521

# %% [markdown]
# Visualize Data (City)

# %%
#City wise Attack

CityAtck = df["city"].value_counts()[1:21]

# %%
CityAtck #Shows the full data
# Out:
# Baghdad           7589
# Karachi           2652
# Lima              2359
# Mosul             2265
# Belfast           2171
# Santiago          1621
# Mogadishu         1581
# San Salvador      1558
# Istanbul          1048
# Athens            1019
# Bogota             984
# Kirkuk             925
# Beirut             918
# Medellin           848
# Benghazi           840
# Peshawar           819
# Quetta             803
# Guatemala City     755
# Baqubah            745
# Kabul              738
# Name: city, dtype: int64

# %%
CityAtck.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
CityAtck.describe() #Inform about important statistical terms depending on Data
# Out:
# count      20.0000
# mean     1611.9000
# std      1536.1905
# min       738.0000
# 25%       834.7500
# 50%      1001.5000
# 75%      1758.5000
# max      7589.0000
# Name: city, dtype: float64

# %%
#Plot Attack Data

CityAtck.plot(kind = "bar", color = "orange", figsize = (20,10))
plt.title("Attacks per City")
plt.xlabel("City")
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# The least number of attacks were in Baqubahth attacks 758
# The most number of attacks were in Baghdad with attacks 8020

# %%
#City wise Casualty

CityCas = df["city"].value_counts()[1:21]

# %%
CityCas.head() #Shows only first 5 rows of the data
# Out:
# Baghdad    7589
# Karachi    2652
# Lima       2359
# Mosul      2265
# Belfast    2171
# Name: city, dtype: int64

# %%
CityCas.tail() ##Shows only last 5 rows of the data
# Out:
# Peshawar          819
# Quetta            803
# Guatemala City    755
# Baqubah           745
# Kabul             738
# Name: city, dtype: int64

# %%
CityCas #Shows the full data
# Out:
# Baghdad           7589
# Karachi           2652
# Lima              2359
# Mosul             2265
# Belfast           2171
# Santiago          1621
# Mogadishu         1581
# San Salvador      1558
# Istanbul          1048
# Athens            1019
# Bogota             984
# Kirkuk             925
# Beirut             918
# Medellin           848
# Benghazi           840
# Peshawar           819
# Quetta             803
# Guatemala City     755
# Baqubah            745
# Kabul              738
# Name: city, dtype: int64

# %%
CityCas.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
CityCas.describe() #Inform about important statistical terms depending on Data
# Out:
# count      20.0000
# mean     1611.9000
# std      1536.1905
# min       738.0000
# 25%       834.7500
# 50%      1001.5000
# 75%      1758.5000
# max      7589.0000
# Name: city, dtype: float64

# %%
#Plot Casualty Data

CityCas.plot(kind = "bar", color = "teal", figsize = (20,10))
plt.title("Casualty per City")
plt.xlabel("City")
plt.ylabel("Casualty")
plt.show()

# %% [markdown]
# The least number of casualties were in Baqubahth casualties 758
# The most number of casualties were in Baghdad with casualties 8020

# %%
#City wise Killed

CityKill = df["city"].value_counts()[1:21]

# %%
CityKill.head() #Shows only first 5 rows of the data
# Out:
# Baghdad    7589
# Karachi    2652
# Lima       2359
# Mosul      2265
# Belfast    2171
# Name: city, dtype: int64

# %%
CityKill.tail() ##Shows only last 5 rows of the data
# Out:
# Peshawar          819
# Quetta            803
# Guatemala City    755
# Baqubah           745
# Kabul             738
# Name: city, dtype: int64

# %%
CityKill #Shows the full data
# Out:
# Baghdad           7589
# Karachi           2652
# Lima              2359
# Mosul             2265
# Belfast           2171
# Santiago          1621
# Mogadishu         1581
# San Salvador      1558
# Istanbul          1048
# Athens            1019
# Bogota             984
# Kirkuk             925
# Beirut             918
# Medellin           848
# Benghazi           840
# Peshawar           819
# Quetta             803
# Guatemala City     755
# Baqubah            745
# Kabul              738
# Name: city, dtype: int64

# %%
CityKill.shape #Gives number of rows and co
# Out:
# (20,)

# %%
CityKill.describe() #Inform about important statistical terms depending on Data
# Out:
# count      20.0000
# mean     1611.9000
# std      1536.1905
# min       738.0000
# 25%       834.7500
# 50%      1001.5000
# 75%      1758.5000
# max      7589.0000
# Name: city, dtype: float64

# %%
#Plot Killed Data

CityKill.plot(kind = "bar", color = "crimson", figsize = (20,10))
plt.title("Killed per City")
plt.xlabel("City")
plt.ylabel("Killed")
plt.show()

# %% [markdown]
# The least number of kills were in Baqubahth kills 758
# The most number of kills were in Baghdad with kills 8020

# %%
#City wise Wounded

CityWoun = df["city"].value_counts()[1:21]

# %%
CityWoun.head() #Shows only first 5 rows of the data
# Out:
# Baghdad    7589
# Karachi    2652
# Lima       2359
# Mosul      2265
# Belfast    2171
# Name: city, dtype: int64

# %%
CityWoun.tail() ##Shows only last 5 rows of the data
# Out:
# Peshawar          819
# Quetta            803
# Guatemala City    755
# Baqubah           745
# Kabul             738
# Name: city, dtype: int64

# %%
CityWoun #Shows the full data
# Out:
# Baghdad           7589
# Karachi           2652
# Lima              2359
# Mosul             2265
# Belfast           2171
# Santiago          1621
# Mogadishu         1581
# San Salvador      1558
# Istanbul          1048
# Athens            1019
# Bogota             984
# Kirkuk             925
# Beirut             918
# Medellin           848
# Benghazi           840
# Peshawar           819
# Quetta             803
# Guatemala City     755
# Baqubah            745
# Kabul              738
# Name: city, dtype: int64

# %%
CityWoun.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
CityWoun.describe() #Inform about important statistical terms depending on Data
# Out:
# count      20.0000
# mean     1611.9000
# std      1536.1905
# min       738.0000
# 25%       834.7500
# 50%      1001.5000
# 75%      1758.5000
# max      7589.0000
# Name: city, dtype: float64

# %%
#Plot Wounded Data

CityWoun.plot(kind = "bar", color = "lightblue", figsize = (20,10))
plt.title("Wounded per City")
plt.xlabel("City")
plt.ylabel("Wounded")
plt.show()

# %% [markdown]
# The least number of wounds were in Baqubahth wounds 758
# The most number of wounds were in Baghdad with wounds 8020

# %% [markdown]
#  Visualize Data (Terrorist Group)

# %%
#Terrorist Group wise Attacks

TGAtck = df["Group"].value_counts()[1:20]

# %%
TGAtck.head() #Shows only first 5 rows of the data
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# Name: Group, dtype: int64

# %%
TGAtck.tail() ##Shows only last 5 rows of the data
# Out:
# National Liberation Army of Colombia (ELN)    1561
# Tehrik-i-Taliban Pakistan (TTP)               1351
# Palestinians                                  1125
# Houthi extremists (Ansar Allah)               1062
# Al-Qaida in the Arabian Peninsula (AQAP)      1020
# Name: Group, dtype: int64

# %%
TGAtck #Shows the full data
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# National Liberation Army of Colombia (ELN)          1561
# Tehrik-i-Taliban Pakistan (TTP)                     1351
# Palestinians                                        1125
# Houthi extremists (Ansar Allah)                     1062
# Al-Qaida in the Arabian Peninsula (AQAP)            1020
# Name: Group, dtype: int64

# %%
TGAtck.shape #Gives number of rows and columns
# Out:
# (19,)

# %%
TGAtck.describe() #Inform about important statistical terms depending on Data
# Out:
# count      19.000000
# mean     2642.105263
# std      1672.030432
# min      1020.000000
# 25%      1583.500000
# 50%      2310.000000
# 75%      3030.000000
# max      7478.000000
# Name: Group, dtype: float64

# %%
#Plot Attack Data

TGAtck.plot(kind = "bar", color = "orange", figsize = (20,10))
plt.title("Attacks per Terrorist Group")
plt.xlabel("Terrorist Group")
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# The least number of attacks were done by Al-Qaida in the Arabian Peninsula (AQAP) with attacks 1113
# The most number of attacks were done by Taliban with attacks 11982

# %%
#Terrorist Group wise Casualty

TGCas = df["Group"].value_counts()[1:20]

# %%
TGCas.head() #Shows only first 5 rows of the data
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# Name: Group, dtype: int64

# %%
TGCas.tail() ##Shows only last 5 rows of the data
# Out:
# National Liberation Army of Colombia (ELN)    1561
# Tehrik-i-Taliban Pakistan (TTP)               1351
# Palestinians                                  1125
# Houthi extremists (Ansar Allah)               1062
# Al-Qaida in the Arabian Peninsula (AQAP)      1020
# Name: Group, dtype: int64

# %%
TGCas #Shows the full data
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# National Liberation Army of Colombia (ELN)          1561
# Tehrik-i-Taliban Pakistan (TTP)                     1351
# Palestinians                                        1125
# Houthi extremists (Ansar Allah)                     1062
# Al-Qaida in the Arabian Peninsula (AQAP)            1020
# Name: Group, dtype: int64

# %%
TGCas.shape #Gives number of rows and columns
# Out:
# (19,)

# %%
TGCas.describe() #Inform about important statistical terms depending on Data
# Out:
# count      19.000000
# mean     2642.105263
# std      1672.030432
# min      1020.000000
# 25%      1583.500000
# 50%      2310.000000
# 75%      3030.000000
# max      7478.000000
# Name: Group, dtype: float64

# %%
#Plot Casualty Data

TGCas.plot(kind = "bar", color = "teal", figsize = (20,10))
plt.title("Casualty per Terrorist Group")
plt.xlabel("Terrorist Group")
plt.ylabel("Casualty")
plt.show()

# %% [markdown]
# The least number of casualties were done by Al-Qaida in the Arabian Peninsula (AQAP) with casualties 1113
# The most number of casualties were done by Taliban with casualties 11982

# %%
#Terrorist Group wise Killed

TGKill = df["Group"].value_counts()[1:20]

# %%
TGKill.head() #Shows only first 5 rows of the data
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# Name: Group, dtype: int64

# %%
TGKill.tail() ##Shows only last 5 rows of the data
# Out:
# National Liberation Army of Colombia (ELN)    1561
# Tehrik-i-Taliban Pakistan (TTP)               1351
# Palestinians                                  1125
# Houthi extremists (Ansar Allah)               1062
# Al-Qaida in the Arabian Peninsula (AQAP)      1020
# Name: Group, dtype: int64

# %%
TGKill #Shows the full data
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# National Liberation Army of Colombia (ELN)          1561
# Tehrik-i-Taliban Pakistan (TTP)                     1351
# Palestinians                                        1125
# Houthi extremists (Ansar Allah)                     1062
# Al-Qaida in the Arabian Peninsula (AQAP)            1020
# Name: Group, dtype: int64

# %%
TGKill.shape #Gives number of rows and columns
# Out:
# (19,)

# %%
TGKill.describe() #Inform about important statistical terms depending on Data
# Out:
# count      19.000000
# mean     2642.105263
# std      1672.030432
# min      1020.000000
# 25%      1583.500000
# 50%      2310.000000
# 75%      3030.000000
# max      7478.000000
# Name: Group, dtype: float64

# %%
#Plot Killed Data

TGKill.plot(kind = "bar", color = "crimson", figsize = (20,10))
plt.title("Killed per Terrorist Group")
plt.xlabel("Terrorist Group")
plt.ylabel("Killed")
plt.show()

# %% [markdown]
# The least number of kills were done by Al-Qaida in the Arabian Peninsula (AQAP) with kills 1113
# The most number of kills were done by Taliban with kills 11982

# %%
#Terrorist Group wise Wounded

TGWoun = df["Group"].value_counts()[1:20]

# %%
TGWoun.head() #Shows only first 5 rows of the data
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# Name: Group, dtype: int64

# %%
TGWoun.tail() ##Shows only last 5 rows of the data
# Out:
# National Liberation Army of Colombia (ELN)    1561
# Tehrik-i-Taliban Pakistan (TTP)               1351
# Palestinians                                  1125
# Houthi extremists (Ansar Allah)               1062
# Al-Qaida in the Arabian Peninsula (AQAP)      1020
# Name: Group, dtype: int64

# %%
TGWoun #Shows the full data
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# National Liberation Army of Colombia (ELN)          1561
# Tehrik-i-Taliban Pakistan (TTP)                     1351
# Palestinians                                        1125
# Houthi extremists (Ansar Allah)                     1062
# Al-Qaida in the Arabian Peninsula (AQAP)            1020
# Name: Group, dtype: int64

# %%
TGWoun.shape #Gives number of rows and columns
# Out:
# (19,)

# %%
TGWoun.describe() #Inform about important statistical terms depending on Data
# Out:
# count      19.000000
# mean     2642.105263
# std      1672.030432
# min      1020.000000
# 25%      1583.500000
# 50%      2310.000000
# 75%      3030.000000
# max      7478.000000
# Name: Group, dtype: float64

# %%
#Plot Wounded Data

TGWoun.plot(kind = "bar", color = "lightblue", figsize = (20,10))
plt.title("Wounded per Terrorist Group")
plt.xlabel("Terrorist Group")
plt.ylabel("Wounded")
plt.show()

# %% [markdown]
# The least number of wounds were done by Al-Qaida in the Arabian Peninsula (AQAP) with wounds 1113
# The most number of wounds were done by Taliban with wounds 11982

# %% [markdown]
# Visualize Data (Attack Type)

# %%
#Attack Type wise Attacks

ATAtck = df["AttackType"].value_counts()

# %%
ATAtck.head() #Shows only first 5 rows of the data
# Out:
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Name: AttackType, dtype: int64

# %%
ATAtck.tail() ##Shows only last 5 rows of the data
# Out:
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
ATAtck #Shows the full data
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
ATAtck.shape #Gives number of rows and columns
# Out:
# (9,)

# %%
ATAtck.describe() #Inform about important statistical terms depending on Data
# Out:
# count        9.000000
# mean     20187.888889
# std      28726.552771
# min        659.000000
# 25%       1015.000000
# 50%      10356.000000
# 75%      19312.000000
# max      88255.000000
# Name: AttackType, dtype: float64

# %%
#Plot Attack Data

ATAtck.plot(kind = "bar", color = "orange", figsize = (20,10))
plt.title("Attacks per Attack Type")
plt.xlabel("Attack Type")
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# The least number of attacks were done by Hijacking with attacks 759
# The most number of attacks were done by Bombing/Explosion with attacks 98158

# %%
#Attack Type wise Casualty

ATCas = df["AttackType"].value_counts()

# %%
ATCas.head() #Shows only first 5 rows of the data
# Out:
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Name: AttackType, dtype: int64

# %%
ATCas.tail() ##Shows only last 5 rows of the data
# Out:
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
ATCas #Shows the full data
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
ATCas.shape #Gives number of rows and columns
# Out:
# (9,)

# %%
ATCas.describe() #Inform about important statistical terms depending on Data
# Out:
# count        9.000000
# mean     20187.888889
# std      28726.552771
# min        659.000000
# 25%       1015.000000
# 50%      10356.000000
# 75%      19312.000000
# max      88255.000000
# Name: AttackType, dtype: float64

# %%
#Plot Casualty Data

ATCas.plot(kind = "bar", color = "teal", figsize = (20,10))
plt.title("Casualty per Attack Type")
plt.xlabel("Attack Type")
plt.ylabel("Casualty")
plt.show()

# %% [markdown]
# The least number of casualties were done by Hijacking with casualties 759
# The most number of casualties were done by Bombing/Explosion with casualties 98158

# %%
#Attack Type wise Killed

ATKill = df["AttackType"].value_counts()

# %%
ATKill.head() #Shows only first 5 rows of the data
# Out:
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Name: AttackType, dtype: int64

# %%
ATKill.tail() ##Shows only last 5 rows of the data
# Out:
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
ATKill #Shows the full data
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
ATKill.shape #Gives number of rows and columns
# Out:
# (9,)

# %%
ATKill.describe() #Inform about important statistical terms depending on Data
# Out:
# count        9.000000
# mean     20187.888889
# std      28726.552771
# min        659.000000
# 25%       1015.000000
# 50%      10356.000000
# 75%      19312.000000
# max      88255.000000
# Name: AttackType, dtype: float64

# %%
#Plot Killed Data

ATKill.plot(kind = "bar", color = "crimson", figsize = (20,10))
plt.title("Killed per Attack Type")
plt.xlabel("Attack Type")
plt.ylabel("Killed")
plt.show()

# %% [markdown]
# The least number of kills were done by Hijacking with kills 759
# The most number of kills were done by Bombing/Explosion with kills 98158

# %%
#Attack Type wise Wounded

ATWoun = df["AttackType"].value_counts()

# %%
ATWoun.head() #Shows only first 5 rows of the data
# Out:
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Name: AttackType, dtype: int64

# %%
ATWoun.tail() ##Shows only last 5 rows of the data
# Out:
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
ATWoun #Shows the full data
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: AttackType, dtype: int64

# %%
ATWoun.shape #Gives number of rows and columns
# Out:
# (9,)

# %%
ATWoun.describe() #Inform about important statistical terms depending on Data
# Out:
# count        9.000000
# mean     20187.888889
# std      28726.552771
# min        659.000000
# 25%       1015.000000
# 50%      10356.000000
# 75%      19312.000000
# max      88255.000000
# Name: AttackType, dtype: float64

# %%
#Plot Wounded Data

ATWoun.plot(kind = "bar", color = "lightblue", figsize = (20,10))
plt.title("Wounded per Attack Type")
plt.xlabel("Attack Type")
plt.ylabel("Wounded")
plt.show()

# %% [markdown]
# The least number of wounds were done by Hijacking with wounds 759
# The most number of wounds were done by Bombing/Explosion with wounds 98158

# %% [markdown]
# Visualize Data (Target Type)

# %%
#Target Type wise Attacks

TTAtck = df["Target_type"].value_counts()

# %%
TTAtck.head() #Shows only first 5 rows of the data
# Out:
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: Target_type, dtype: int64

# %%
TTAtck.tail() ##Shows only last 5 rows of the data
# Out:
# Tourists                440
# Maritime                351
# Food or Water Supply    317
# Abortion Related        263
# Other                   137
# Name: Target_type, dtype: int64

# %%
TTAtck #Shows the full data
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target_type, dtype: int64

# %%
TTAtck.shape #Gives number of rows and columns
# Out:
# (22,)

# %%
TTAtck.describe() #Inform about important statistical terms depending on Data
# Out:
# count       22.000000
# mean      8258.681818
# std      11650.926574
# min        137.000000
# 25%        979.750000
# 50%       3306.000000
# 75%       6605.000000
# max      43511.000000
# Name: Target_type, dtype: float64

# %%
#Plot Attack Data

TTAtck.plot(kind = "bar", color = "orange", figsize = (20,10))
plt.title("Attacks per Target Type")
plt.xlabel("Target Type")
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# The least number of attacks were on other with attacks 197
# The most number of attacks were on Private Property and Citizens with attacks 51985

# %%
#Target Type wise Casualty

TTCas = df["Target_type"].value_counts()

# %%
TTCas.head() #Shows only first 5 rows of the data
# Out:
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: Target_type, dtype: int64

# %%
TTCas.tail() ##Shows only last 5 rows of the data
# Out:
# Tourists                440
# Maritime                351
# Food or Water Supply    317
# Abortion Related        263
# Other                   137
# Name: Target_type, dtype: int64

# %%
TTCas #Shows the full data
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target_type, dtype: int64

# %%
TTCas.shape #Gives number of rows and columns
# Out:
# (22,)

# %%
TTCas.describe() #Inform about important statistical terms depending on Data
# Out:
# count       22.000000
# mean      8258.681818
# std      11650.926574
# min        137.000000
# 25%        979.750000
# 50%       3306.000000
# 75%       6605.000000
# max      43511.000000
# Name: Target_type, dtype: float64

# %%
#Plot Casualty Data

TTCas.plot(kind = "bar", color = "teal", figsize = (20,10))
plt.title("Casualty per Target Type")
plt.xlabel("Target Type")
plt.ylabel("Casualty")
plt.show()

# %% [markdown]
# The least number of casualties were on other with casualties 197
# The most number of casualties were on Private Property and Citizens with casualties 51985

# %%
#Target Type wise Killed

TTKill = df["Target_type"].value_counts()

# %%
TTKill.head() #Shows only first 5 rows of the data
# Out:
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: Target_type, dtype: int64

# %%
TTKill.tail() ##Shows only last 5 rows of the data
# Out:
# Tourists                440
# Maritime                351
# Food or Water Supply    317
# Abortion Related        263
# Other                   137
# Name: Target_type, dtype: int64

# %%
TTKill #Shows the full data
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target_type, dtype: int64

# %%
TTKill.shape #Gives number of rows and columns
# Out:
# (22,)

# %%
TTKill.describe() #Inform about important statistical terms depending on Data
# Out:
# count       22.000000
# mean      8258.681818
# std      11650.926574
# min        137.000000
# 25%        979.750000
# 50%       3306.000000
# 75%       6605.000000
# max      43511.000000
# Name: Target_type, dtype: float64

# %%
#Plot Killed Data

TTKill.plot(kind = "bar", color = "crimson", figsize = (20,10))
plt.title("Killed per Target Type")
plt.xlabel("Target Type")
plt.ylabel("Killed")
plt.show()

# %% [markdown]
# The least number of kills were on other with kills 197
# The most number of kills were on Private Property and Citizens with kills 51985

# %%
#Target Type wise Wounded

TTWoun = df["Target_type"].value_counts()

# %%
TTWoun.head() #Shows only first 5 rows of the data
# Out:
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: Target_type, dtype: int64

# %%
TTWoun.tail() ##Shows only last 5 rows of the data
# Out:
# Tourists                440
# Maritime                351
# Food or Water Supply    317
# Abortion Related        263
# Other                   137
# Name: Target_type, dtype: int64

# %%
TTWoun #Shows the full data
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target_type, dtype: int64

# %%
TTWoun.shape #Gives number of rows and columns
# Out:
# (22,)

# %%
TTWoun.describe() #Inform about important statistical terms depending on Data
# Out:
# count       22.000000
# mean      8258.681818
# std      11650.926574
# min        137.000000
# 25%        979.750000
# 50%       3306.000000
# 75%       6605.000000
# max      43511.000000
# Name: Target_type, dtype: float64

# %%
#Plot Wounded Data

TTWoun.plot(kind = "bar", color = "lightblue", figsize = (20,10))
plt.title("Wounded per Target Type")
plt.xlabel("Target Type")
plt.ylabel("Wounded")
plt.show()

# %% [markdown]
# The least number of wounds were on other with wounds 197
# The most number of wounds were on Private Property and Citizens with wounds 51985

# %% [markdown]
# Visualize Data (Country and Group)

# %%
#Terrorist Group and Country wise Attacks

TCAtck = df[["Group", "Country"]].value_counts().drop("Unknown").head(20)

# %%
TCAtck.head() #Shows only first 5 rows of the data
# Out:
# Group                                             Country
# Taliban                                           Afghanistan    7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq           4797
# Shining Path (SL)                                 Peru           4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador    3330
# Al-Shabaab                                        Somalia        2867
# dtype: int64

# %%
TCAtck.tail() ##Shows only last 5 rows of the data
# Out:
# Group                                     Country
# Tehrik-i-Taliban Pakistan (TTP)           Pakistan     1335
# Al-Qaida in the Arabian Peninsula (AQAP)  Yemen        1007
# Houthi extremists (Ansar Allah)           Yemen         908
# Nicaraguan Democratic Force (FDN)         Nicaragua     886
# Manuel Rodriguez Patriotic Front (FPMR)   Chile         829
# dtype: int64

# %%
TCAtck #Shows the full data
# Out:
# Group                                             Country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# Boko Haram                                        Nigeria           2087
# Basque Fatherland and Freedom (ETA)               Spain             1975
# Communist Party of India - Maoist (CPI-Maoist)    India             1877
# Liberation Tigers of Tamil Eelam (LTTE)           Sri Lanka         1596
# National Liberation Army of Colombia (ELN)        Colombia          1529
# Maoists                                           India             1396
# Tehrik-i-Taliban Pakistan (TTP)                   Pakistan          1335
# Al-Qaida in the Arabian Peninsula (AQAP)          Yemen             1007
# Houthi extremists (Ansar Allah)                   Yemen              908
# Nicaraguan Democratic Force (FDN)                 Nicaragua          886
# Manuel Rodriguez Patriotic Front (FPMR)           Chile              829
# dtype: int64

# %%
TCAtck.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
TCAtck.describe() #Inform about important statistical terms depending on Data
# Out:
# count      20.000000
# mean     2415.250000
# std      1620.937964
# min       829.000000
# 25%      1380.750000
# 50%      2031.000000
# 75%      2794.250000
# max      7423.000000
# dtype: float64

# %%
#Plot Attack Data

TCAtck.plot(kind = "bar", color = "orange", figsize = (20,10))
plt.title("Countries Attacked by Terrorist Group")
plt.xlabel("Terrorist Group, Country")
plt.xticks()
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# The least number of attacks were done by Nicaraguan Democratic Force (FDN) in Nicaragua with attacks 886
# The most number of attacks were done by Taliban in Afghanistan with attacks 11926

# %%
#Terrorist Group and Country wise Casualty

TCCas = df[["Group", "Country"]].value_counts().drop("Unknown").head(20)

# %%
TCCas.head() #Shows only first 5 rows of the data
# Out:
# Group                                             Country
# Taliban                                           Afghanistan    7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq           4797
# Shining Path (SL)                                 Peru           4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador    3330
# Al-Shabaab                                        Somalia        2867
# dtype: int64

# %%
TCCas.tail() ##Shows only last 5 rows of the data
# Out:
# Group                                     Country
# Tehrik-i-Taliban Pakistan (TTP)           Pakistan     1335
# Al-Qaida in the Arabian Peninsula (AQAP)  Yemen        1007
# Houthi extremists (Ansar Allah)           Yemen         908
# Nicaraguan Democratic Force (FDN)         Nicaragua     886
# Manuel Rodriguez Patriotic Front (FPMR)   Chile         829
# dtype: int64

# %%
TCCas #Shows the full data
# Out:
# Group                                             Country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# Boko Haram                                        Nigeria           2087
# Basque Fatherland and Freedom (ETA)               Spain             1975
# Communist Party of India - Maoist (CPI-Maoist)    India             1877
# Liberation Tigers of Tamil Eelam (LTTE)           Sri Lanka         1596
# National Liberation Army of Colombia (ELN)        Colombia          1529
# Maoists                                           India             1396
# Tehrik-i-Taliban Pakistan (TTP)                   Pakistan          1335
# Al-Qaida in the Arabian Peninsula (AQAP)          Yemen             1007
# Houthi extremists (Ansar Allah)                   Yemen              908
# Nicaraguan Democratic Force (FDN)                 Nicaragua          886
# Manuel Rodriguez Patriotic Front (FPMR)           Chile              829
# dtype: int64

# %%
TCCas.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
TCCas.describe() #Inform about important statistical terms depending on Data
# Out:
# count      20.000000
# mean     2415.250000
# std      1620.937964
# min       829.000000
# 25%      1380.750000
# 50%      2031.000000
# 75%      2794.250000
# max      7423.000000
# dtype: float64

# %%
#Plot Casualty Data

TCCas.plot(kind = "bar", color = "teal", figsize = (20,10))
plt.title("Countries Casualty by Terrorist Group")
plt.xlabel("Terrorist Group, Country")
plt.ylabel("Casualty")
plt.show()

# %% [markdown]
# The least number of casualties were done by Nicaraguan Democratic Force (FDN) in Nicaragua with casualties 886
# The most number of casualties were done by Taliban in Afghanistan with casualties 11926

# %%
#Terrorist Group and Country wise Killed

TCKill = df[["Group", "Country"]].value_counts().drop("Unknown").head(20)

# %%
TCKill.head() #Shows only first 5 rows of the data
# Out:
# Group                                             Country
# Taliban                                           Afghanistan    7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq           4797
# Shining Path (SL)                                 Peru           4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador    3330
# Al-Shabaab                                        Somalia        2867
# dtype: int64

# %%
TCKill.tail() ##Shows only last 5 rows of the data
# Out:
# Group                                     Country
# Tehrik-i-Taliban Pakistan (TTP)           Pakistan     1335
# Al-Qaida in the Arabian Peninsula (AQAP)  Yemen        1007
# Houthi extremists (Ansar Allah)           Yemen         908
# Nicaraguan Democratic Force (FDN)         Nicaragua     886
# Manuel Rodriguez Patriotic Front (FPMR)   Chile         829
# dtype: int64

# %%
TCKill #Shows the full data
# Out:
# Group                                             Country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# Boko Haram                                        Nigeria           2087
# Basque Fatherland and Freedom (ETA)               Spain             1975
# Communist Party of India - Maoist (CPI-Maoist)    India             1877
# Liberation Tigers of Tamil Eelam (LTTE)           Sri Lanka         1596
# National Liberation Army of Colombia (ELN)        Colombia          1529
# Maoists                                           India             1396
# Tehrik-i-Taliban Pakistan (TTP)                   Pakistan          1335
# Al-Qaida in the Arabian Peninsula (AQAP)          Yemen             1007
# Houthi extremists (Ansar Allah)                   Yemen              908
# Nicaraguan Democratic Force (FDN)                 Nicaragua          886
# Manuel Rodriguez Patriotic Front (FPMR)           Chile              829
# dtype: int64

# %%
TCKill.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
TCKill.describe() #Inform about important statistical terms depending on Data
# Out:
# count      20.000000
# mean     2415.250000
# std      1620.937964
# min       829.000000
# 25%      1380.750000
# 50%      2031.000000
# 75%      2794.250000
# max      7423.000000
# dtype: float64

# %%
#Plot Killed Data

TCKill.plot(kind = "bar", color = "crimson", figsize = (20,10))
plt.title("Countries Killed by Terrorist Group")
plt.xlabel("Terrorist Group, Country")
plt.ylabel("Killed")
plt.show()

# %% [markdown]
# The least number of kills were done by Nicaraguan Democratic Force (FDN) in Nicaragua with kills 886
# The most number of kills were done by Taliban in Afghanistan with kills 11926

# %%
#Terrorist Group and Country wise Wounded

TCWoun = df[["Group", "Country"]].value_counts().drop("Unknown").head(20)

# %%
TCWoun.head() #Shows only first 5 rows of the data
# Out:
# Group                                             Country
# Taliban                                           Afghanistan    7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq           4797
# Shining Path (SL)                                 Peru           4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador    3330
# Al-Shabaab                                        Somalia        2867
# dtype: int64

# %%
TCWoun.tail() ##Shows only last 5 rows of the data
# Out:
# Group                                     Country
# Tehrik-i-Taliban Pakistan (TTP)           Pakistan     1335
# Al-Qaida in the Arabian Peninsula (AQAP)  Yemen        1007
# Houthi extremists (Ansar Allah)           Yemen         908
# Nicaraguan Democratic Force (FDN)         Nicaragua     886
# Manuel Rodriguez Patriotic Front (FPMR)   Chile         829
# dtype: int64

# %%
TCWoun #Shows the full data
# Out:
# Group                                             Country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# Boko Haram                                        Nigeria           2087
# Basque Fatherland and Freedom (ETA)               Spain             1975
# Communist Party of India - Maoist (CPI-Maoist)    India             1877
# Liberation Tigers of Tamil Eelam (LTTE)           Sri Lanka         1596
# National Liberation Army of Colombia (ELN)        Colombia          1529
# Maoists                                           India             1396
# Tehrik-i-Taliban Pakistan (TTP)                   Pakistan          1335
# Al-Qaida in the Arabian Peninsula (AQAP)          Yemen             1007
# Houthi extremists (Ansar Allah)                   Yemen              908
# Nicaraguan Democratic Force (FDN)                 Nicaragua          886
# Manuel Rodriguez Patriotic Front (FPMR)           Chile              829
# dtype: int64

# %%
TCWoun.shape #Gives number of rows and columns
# Out:
# (20,)

# %%
TCWoun.describe() #Inform about important statistical terms depending on Data
# Out:
# count      20.000000
# mean     2415.250000
# std      1620.937964
# min       829.000000
# 25%      1380.750000
# 50%      2031.000000
# 75%      2794.250000
# max      7423.000000
# dtype: float64

# %%
#Plot Wounded Data

TCWoun.plot(kind = "bar", color = "lightblue", figsize = (20,10))
plt.title("Countries Wounded by Terrorist Group")
plt.xlabel("Terrorist Group, Country")
plt.ylabel("Wounded")
plt.show()

# %% [markdown]
# The least number of wounds were done by Nicaraguan Democratic Force (FDN) in Nicaragua with wounds 886
# The most number of wounds were done by Taliban in Afghanistan with wounds 11926

# %%
#Casualty

Cas = df.loc[:, "Casualty"].sum()

print("Total number of Casualties accross the world from 1970 to 2020 : ", Cas)
# Out:
# Total number of Casualties accross the world from 1970 to 2020 :  935737.0

# %%
#Killed

Kill = df.loc[:, "Killed"].sum()

print("Total number of Killed accross the world from 1970 to 2020 : ", Kill)
# Out:
# Total number of Killed accross the world from 1970 to 2020 :  411868.0

# %%
#Wounded

Woun = df.loc[:, "Wounded"].sum()

print("Total number of Wounded accross the world from 1970 to 2020 : ", Woun)
# Out:
# Total number of Wounded accross the world from 1970 to 2020 :  523869.0

# %% [markdown]
#  Conclusions
#  Total number of Casualties accross the world from 1970 to 2020 :  935736
#  Total number of Killed accross the world from 1970 to 2020 :  411868
#  Total number of Wounded accross the world from 1970 to 2020 :  523868
